# %%
import pandas as pd
import numpy as np
from sklearn import svm

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# %%
recipes=pd.read_csv('recipes_muffins_cupcakes.csv')
recipes.head()
# Out:
#      Type  Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt
# 0  Muffin     55    28      3       7    5              2        0     0
# 1  Muffin     47    24     12       6    9              1        0     0
# 2  Muffin     47    23     18       6    4              1        0     0
# 3  Muffin     45    11     17      17    8              1        0     0
# 4  Muffin     50    25     12       6    5              2        1     0

# %%
sns.lmplot('Sugar','Flour',data= recipes,hue='Type',palette='Set1',fit_reg=True,scatter_kws={"s":50})
# Out:
# c:\Users\Hariprasath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sugar_butter=recipes[['Sugar','Flour']].values
type_label=np.where(recipes['Type']=='Muffin',0,1)

# %%
print(sugar_butter)
# Out:
# [[ 3 55]
#  [12 47]
#  [18 47]
#  [17 45]
#  [12 50]
#  [ 3 55]
#  [ 7 54]
#  [10 47]
#  [17 50]
#  [17 50]
#  [26 39]
#  [16 42]
#  [20 34]
#  [17 39]
#  [23 38]
#  [25 42]
#  [21 36]
#  [31 38]
#  [24 36]
#  [23 34]]

# %%
model = svm.SVC(kernel='linear')
model.fit(sugar_butter,type_label)
# Out:
# SVC(kernel='linear')

# %%
w=model.coef_[0]
a=-w[0]/w[1]
xx=np.linspace(5,30)
yy=a*xx-(model.intercept_[0])/w[1]

# %%
b=model.support_vectors_[0]
yy_down=a*xx+(b[1]-a*b[0])
b=model.support_vectors_[-1]
yy_up=a*xx+(b[1]-a*b[0])

# %%
sns.lmplot('Sugar','Flour',data=recipes,hue='Type',palette='Set1',fit_reg=False,scatter_kws={"s":70})
plt.plot(xx,yy,linewidth=2,color='black')
# Out:
# c:\Users\Hariprasath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Sugar','Flour',data=recipes,hue='Type',palette='Set1',fit_reg=False,scatter_kws={"s":70})
plt.plot(xx,yy,linewidth=2,color='black')
plt.plot(xx,yy_down,'k--') 
plt.plot(xx,yy_up,'k--')
plt.scatter(model.support_vectors_[:.0],model,support_vectors_[:,1],s=80,facecolors='none' )
# Out:
# c:\Users\Hariprasath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HARIPR~1\AppData\Local\Temp/ipykernel_19120/1505967312.py in <module>
#       3 plt.plot(xx,yy_down,'k--')
#       4 plt.plot(xx,yy_up,'k--')
# ----> 5 plt.scatter(model.support_vectors_[:.0],model,support_vectors_[:,1],s=80,facecolors='none' )
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(sugar_butter, type_label, test_size=0.2)

# %%
model1 = svm.SVC(kernel='linear')
model1.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
pred = model1.predict(x_test)
print(pred)
# Out:
# [0 0 1 0]

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[3 0]
#  [0 1]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
